# %%
"""
Phase-1 Validation
------------------
Finds <repo>/data/processed/clean_hdb.csv from anywhere and sanity-checks it.
Run as .py or in a notebook; paths auto-resolve.
"""
# 1. Imports
from pathlib import Path
import pandas as pd
import sys

# 2. Locate the CSV
try:
    START_DIR = Path(__file__).resolve().parent      # script mode
except NameError:
    START_DIR = Path.cwd()                           # notebook mode
    print(f"📓 notebook run; cwd = {START_DIR}")

target_rel = Path("data/processed/clean_hdb.csv")
root = START_DIR
while not (root / target_rel).exists():
    if root == root.parent:
        sys.exit(f"❌ Could not find {target_rel} above {START_DIR}")
    root = root.parent

CLEAN_PATH = root / target_rel
print(f"🔍 Using clean file at → {CLEAN_PATH.relative_to(root)}")

# 3. Load
df = pd.read_csv(CLEAN_PATH)
print(f"✅ Loaded {len(df):,} rows · {df.shape[1]} columns")

# 5. Checks
req_cols = ["sale_date","sale_year","sale_month","resale_price",
            "floor_area_sqm","price_per_sqm","lease_remaining_years","flat_age"]
missing = [c for c in req_cols if c not in df.columns]
assert not missing, f"❌ Missing cols: {missing}"
print("✅ Essential columns present")

assert df.duplicated().sum() == 0, "❌ Duplicate rows found"
print("✅ No duplicate rows")

num_cols = ["resale_price","floor_area_sqm",
            "price_per_sqm","lease_remaining_years","flat_age"]
bad = {c:str(df[c].dtype) for c in num_cols if not pd.api.types.is_numeric_dtype(df[c])}
assert not bad, f"❌ Non-numeric dtypes: {bad}"
print("✅ Numeric columns really numeric")

null_pc = df.isna().mean().round(3)
warn = null_pc[null_pc > 0.02]
if not warn.empty:
    print("⚠️  >2 % nulls:\n", warn)
else:
    print("✅ Nulls ≤2 % everywhere")

assert (df["resale_price"] > 1_000).all(), "❌ Weird resale_price values"
print("✅ resale_price values positive")

print("\n🎉 Phase 1 data passes all basic checks.\n")

print(
    df[["resale_price","price_per_sqm",
        "lease_remaining_years","flat_age"]].describe().T
)
print(df.info())
print(df.flat_type.head(50))
# Out:
# 📓 notebook run; cwd = /Users/sheenal/Desktop/hdb-price-predictor/rough
# 🔍 Using clean file at → data/processed/clean_hdb.csv
# ✅ Loaded 957,585 rows · 49 columns
# ✅ Essential columns present
# ✅ No duplicate rows
# ✅ Numeric columns really numeric
# ✅ Nulls ≤2 % everywhere
# ✅ resale_price values positive
#
# 🎉 Phase 1 data passes all basic checks.
#
#                           count           mean            std           min  \
# resale_price           957585.0  331389.762439  180194.108238  20000.000000
# price_per_sqm          957585.0    3433.137734    1650.306901    252.380952
# lease_remaining_years  957534.0      80.730636      11.069681     40.000000
# flat_age               957534.0      18.161688      10.995329      0.000000
#
#                             25%            50%            75%           max
# resale_price           198000.0  305000.000000  430000.000000  1.658888e+06
# price_per_sqm            2312.5    3021.978022    4347.826087  1.614894e+04
# lease_remaining_years      74.0      83.000000      90.000000  9.900000e+01
# flat_age                    9.0      16.000000      25.000000  5.900000e+01
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957585 entries, 0 to 957584
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   _id                         957585 non-null  int64
#  1   month                       957585 non-null  object
#  2   town                        957585 non-null  object
#  3   flat_type                   957585 non-null  object
#  4   block                       957585 non-null  object
#  5   street_name                 957585 non-null  object
#  6   storey_range                957585 non-null  object
#  7   floor_area_sqm              957585 non-null  float64
#  8   flat_model                  957585 non-null  object
#  9   lease_commence_date         957585 non-null  int64
#  10  resale_price                957585 non-null  float64
#  11  sale_date                   957585 non-null  object
#  12  sale_year                   957585 non-null  int64
#  13  sale_month                  957585 non-null  int64
#  14  price_per_sqm               957585 non-null  float64
#  15  lease_remaining_years       957534 non-null  float64
#  16  flat_age                    957534 non-null  float64
#  17  town_bedok                  957585 non-null  bool
#  18  town_bishan                 957585 non-null  bool
#  19  town_bukit_batok            957585 non-null  bool
#  20  town_bukit_merah            957585 non-null  bool
#  21  town_bukit_panjang          957585 non-null  bool
#  22  town_bukit_timah            957585 non-null  bool
#  23  town_central_area           957585 non-null  bool
#  24  town_choa_chu_kang          957585 non-null  bool
#  25  town_clementi               957585 non-null  bool
#  26  town_geylang                957585 non-null  bool
#  27  town_hougang                957585 non-null  bool
#  28  town_jurong_east            957585 non-null  bool
#  29  town_jurong_west            957585 non-null  bool
#  30  town_kallang_whampoa        957585 non-null  bool
#  31  town_lim_chu_kang           957585 non-null  bool
#  32  town_marine_parade          957585 non-null  bool
#  33  town_pasir_ris              957585 non-null  bool
#  34  town_punggol                957585 non-null  bool
#  35  town_queenstown             957585 non-null  bool
#  36  town_sembawang              957585 non-null  bool
#  37  town_sengkang               957585 non-null  bool
#  38  town_serangoon              957585 non-null  bool
#  39  town_tampines               957585 non-null  bool
#  40  town_toa_payoh              957585 non-null  bool
#  41  town_woodlands              957585 non-null  bool
#  42  town_yishun                 957585 non-null  bool
#  43  flat_type_2_room            957585 non-null  bool
#  44  flat_type_3_room            957585 non-null  bool
#  45  flat_type_4_room            957585 non-null  bool
#  46  flat_type_5_room            957585 non-null  bool
#  47  flat_type_executive         957585 non-null  bool
#  48  flat_type_multi_generation  957585 non-null  bool
# dtypes: bool(32), float64(5), int64(4), object(8)
# memory usage: 153.4+ MB
# None
# 0     3 ROOM
# 1     3 ROOM
# 2     3 ROOM
# 3     3 ROOM
# 4     3 ROOM
# 5     3 ROOM
# 6     3 ROOM
# 7     3 ROOM
# 8     3 ROOM
# 9     3 ROOM
# 10    3 ROOM
# 11    3 ROOM
# 12    3 ROOM
# 13    3 ROOM
# 14    3 ROOM
# 15    3 ROOM
# 16    3 ROOM
# 17    3 ROOM
# 18    3 ROOM
# 19    3 ROOM
# 20    3 ROOM
# 21    3 ROOM
# 22    3 ROOM
# 23    3 ROOM
# 24    3 ROOM
# 25    3 ROOM
# 26    3 ROOM
# 27    3 ROOM
# 28    3 ROOM
# 29    3 ROOM
# 30    3 ROOM
# 31    3 ROOM
# 32    3 ROOM
# 33    3 ROOM
# 34    3 ROOM
# 35    3 ROOM
# 36    3 ROOM
# 37    3 ROOM
# 38    3 ROOM
# 39    3 ROOM
# 40    3 ROOM
# 41    3 ROOM
# 42    3 ROOM
# 43    3 ROOM
# 44    3 ROOM
# 45    3 ROOM
# 46    3 ROOM
# 47    3 ROOM
# 48    3 ROOM
# 49    3 ROOM
# Name: flat_type, dtype: object
